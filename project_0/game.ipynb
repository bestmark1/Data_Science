# %% [markdown]
# # Игра угадай число

# %%
from game_v2 import score_game, binary_predict
# Out:
# Ваш алгоритм угадывает число в среднем за: 5 попыток
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from game_v2 import score_game, random_predict
#
# ImportError: cannot import name 'random_predict' from 'game_v2' (/Users/bestmark1/Documents/VS Code/project_0/game_v2.py)

# %% [markdown]
# ## Угадываем рандомно:

# %%
score_game(binary_predict) #вызов функции
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 score_game(random_predict) #вызов функции
#
# NameError: name 'score_game' is not defined
